# %%
import pandas as pd

# %%
HeroInfo = pd.read_csv("../data/HeroInfo.csv",encoding='utf-8')

# %%
HeroInfo.head()
# Out:
#               Name Character Score Intelligence Strength Speed Durability  \
# 0             Zoom               9           50       10   100         30
# 1          Zatanna              10           85       10    25         30
# 2             Yoda              13           90       55    35         25
# 3             Ymir              11           50      100    30        100
# 4  Yellowjacket II               4           50       10    35         30
#
#   Power Combat        FullName             AlterEgos          ...            \
# 0   100     30  Hunter Zolomon             Zoom (CW)          ...
# 1   100     60  Zatanna Zatara  No alter egos found.          ...
# 2   100     90            Yoda  No alter egos found.          ...
# 3   100     30            Ymir  No alter egos found.          ...
# 4    35     30     Rita DeMara  No alter egos found.          ...
#
#   Alignment  Gender            Race                Height           Weight  \
# ...

# %%
HeroInfo.shape
# Out:
# (748, 24)

# %%
HeroInfo.count()
# Out:
# Name               748
# Character Score    742
# Intelligence       742
# Strength           742
# Speed              742
# Durability         742
# Power              742
# Combat             742
# FullName           742
# AlterEgos          742
# Aliases            742
# PlaceOfBirth       742
# FirstAppearance    742
# Publisher          724
# Alignment          742
# Gender             742
# Race               742
# Height             742
# Weight             742
# EyeColor           742
# HairColor          742
# SkinColor          742
# Occupation         742
# Base               742
# dtype: int64

# %%
HeroInfo.get_dtype_counts()
# Out:
# object    24
# dtype: int64

# %%
HeroInfo.shape
# Out:
# (748, 24)

# %%
for i in range(0,748) :
    a = HeroInfo.iloc[i].str.replace('-','NaN')
    HeroInfo.iloc[i] = a

# %%
HeroInfo = HeroInfo.fillna('NaN')

# %%
HeroInfo.head()
# Out:
#               Name Character Score Intelligence Strength Speed Durability  \
# 0             Zoom               9           50       10   100         30
# 1          Zatanna              10           85       10    25         30
# 2             Yoda              13           90       55    35         25
# 3             Ymir              11           50      100    30        100
# 4  Yellowjacket II               4           50       10    35         30
#
#   Power Combat        FullName             AlterEgos          ...            \
# 0   100     30  Hunter Zolomon             Zoom (CW)          ...
# 1   100     60  Zatanna Zatara  No alter egos found.          ...
# 2   100     90            Yoda  No alter egos found.          ...
# 3   100     30            Ymir  No alter egos found.          ...
# 4    35     30     Rita DeMara  No alter egos found.          ...
#
#   Alignment  Gender            Race                Height           Weight  \
# ...

# %%
HeroInfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 24 columns):
# Name               748 non-null object
# Character Score    748 non-null object
# Intelligence       748 non-null object
# Strength           748 non-null object
# Speed              748 non-null object
# Durability         748 non-null object
# Power              748 non-null object
# Combat             748 non-null object
# FullName           748 non-null object
# AlterEgos          748 non-null object
# Aliases            748 non-null object
# PlaceOfBirth       748 non-null object
# FirstAppearance    748 non-null object
# Publisher          748 non-null object
# Alignment          748 non-null object
# Gender             748 non-null object
# Race               748 non-null object
# Height             748 non-null object
# Weight             748 non-null object
# EyeColor           748 non-null object
# HairColor          748 non-null object
# ...

# %%
HeroInfo.columns
# Out:
# Index(['Name', 'Character Score', 'Intelligence', 'Strength', 'Speed',
#        'Durability', 'Power', 'Combat', 'FullName', 'AlterEgos', 'Aliases',
#        'PlaceOfBirth', 'FirstAppearance', 'Publisher', 'Alignment', 'Gender',
#        'Race', 'Height', 'Weight', 'EyeColor', 'HairColor', 'SkinColor',
#        'Occupation', 'Base'],
#       dtype='object')

# %%
cols = ['Character Score', 'Intelligence', 'Strength', 'Speed','Durability', 'Power', 'Combat']

# %%
for c in cols :
    HeroInfo[c] = HeroInfo[c].astype('float')
    HeroInfo[c] = HeroInfo[c].fillna(0)

# %%
HeroInfo.dtypes
# Out:
# Name                object
# Character Score    float64
# Intelligence       float64
# Strength           float64
# Speed              float64
# Durability         float64
# Power              float64
# Combat             float64
# FullName            object
# AlterEgos           object
# Aliases             object
# PlaceOfBirth        object
# FirstAppearance     object
# Publisher           object
# Alignment           object
# Gender              object
# Race                object
# Height              object
# Weight              object
# EyeColor            object
# HairColor           object
# SkinColor           object
# Occupation          object
# Base                object
# dtype: object

# %%
HeroInfo.isnull().sum()
# Out:
# Name               0
# Character Score    0
# Intelligence       0
# Strength           0
# Speed              0
# Durability         0
# Power              0
# Combat             0
# FullName           0
# AlterEgos          0
# Aliases            0
# PlaceOfBirth       0
# FirstAppearance    0
# Publisher          0
# Alignment          0
# Gender             0
# Race               0
# Height             0
# Weight             0
# EyeColor           0
# HairColor          0
# SkinColor          0
# Occupation         0
# Base               0
# dtype: int64

# %%
HeroInfo.memory_usage(deep=True)
# Out:
# Index                 80
# Name               49543
# Character Score     5984
# Intelligence        5984
# Strength            5984
# Speed               5984
# Durability          5984
# Power               5984
# Combat              5984
# FullName           52073
# AlterEgos          58121
# Aliases            66023
# PlaceOfBirth       50584
# FirstAppearance    62910
# Publisher          51190
# Alignment          45490
# Gender             45997
# Race               46552
# Height             52004
# Weight             53732
# EyeColor           45777
# HairColor          46223
# SkinColor          45022
# Occupation         62680
# Base               60463
# dtype: int64

# %%
help(HeroInfo.filter)
# Out:
# Help on method filter in module pandas.core.generic:
#
# filter(items=None, like=None, regex=None, axis=None) method of pandas.core.frame.DataFrame instance
#     Subset rows or columns of dataframe according to labels in
#     the specified index.
#
#     Note that this routine does not filter a dataframe on its
#     contents. The filter is applied to the labels of the index.
#
#     Parameters
#     ----------
#     items : list-like
#         List of info axis to restrict to (must not all be present)
#     like : string
#         Keep info axis where "arg in col == True"
#     regex : string (regular expression)
#         Keep info axis with re.search(regex, col) == True
#     axis : int or string axis name
#         The axis to filter on.  By default this is the info axis,
#         'index' for Series, 'columns' for DataFrame
#
#     Returns
#     -------
#     same type as input object
#
#     Examples
#     --------
#     >>> df
#     one  two  three
# ...

# %%
HeroInfo.shape
# Out:
# (748, 24)

# %%
a = HeroInfo.filter(items=[ 'Character Score', 'Intelligence',
                           'Strength','Speed','Durability','Power','Combat'])

# %%
a.shape
# Out:
# (748, 7)

# %%
a.head()
# Out:
#    Character Score  Intelligence  Strength  Speed  Durability  Power  Combat
# 0              9.0          50.0      10.0  100.0        30.0  100.0    30.0
# 1             10.0          85.0      10.0   25.0        30.0  100.0    60.0
# 2             13.0          90.0      55.0   35.0        25.0  100.0    90.0
# 3             11.0          50.0     100.0   30.0       100.0  100.0    30.0
# 4              4.0          50.0      10.0   35.0        30.0   35.0    30.0

# %%
a.sort_values(['Character Score'],ascending=False).head()
# Out:
#      Character Score  Intelligence  Strength  Speed  Durability  Power  Combat
# 74             231.0         100.0     100.0  100.0       100.0  100.0   100.0
# 236            185.0         100.0     100.0  100.0       100.0  100.0   100.0
# 313            175.0         100.0     100.0  100.0       100.0  100.0   100.0
# 330            128.0         100.0     100.0  100.0       100.0  100.0    30.0
# 119            108.0          90.0     100.0  100.0       100.0  100.0    70.0

# %%
a.nlargest(100, 'Character Score')
# Out:
#      Character Score  Intelligence  Strength  Speed  Durability  Power  Combat
# 74             231.0         100.0     100.0  100.0       100.0  100.0   100.0
# 236            185.0         100.0     100.0  100.0       100.0  100.0   100.0
# 313            175.0         100.0     100.0  100.0       100.0  100.0   100.0
# 330            128.0         100.0     100.0  100.0       100.0  100.0    30.0
# 119            108.0          90.0     100.0  100.0       100.0  100.0    70.0
# 742            103.0         100.0     100.0   85.0       100.0  100.0    55.0
# 203             90.0         100.0      15.0   20.0       100.0  100.0    40.0
# 477             80.0          65.0      80.0   50.0        60.0  100.0    50.0
# 473             74.0         100.0     100.0   85.0       100.0  100.0    50.0
# 221             71.0         100.0      10.0   25.0       100.0  100.0    40.0
# 716             70.0          90.0     100.0   50.0       100.0  100.0    90.0
# ...

# %%
HeroInfo.nlargest(100, 'Character Score').nsmallest(10,'Combat')
# Out:
#                  Name  Character Score  Intelligence  Strength  Speed  \
# 459          Godzilla             15.0          45.0     100.0   55.0
# 706            Ardina             21.0          65.0     100.0  100.0
# 330   Living Tribunal            128.0         100.0     100.0  100.0
# 646       Black Flash             18.0          45.0      10.0  100.0
# 133     Silver Surfer             47.0          60.0     100.0  100.0
# 203                 Q             90.0         100.0      15.0   20.0
# 221  Phantom Stranger             71.0         100.0      10.0   25.0
# 150            Sentry             23.0          75.0     100.0  100.0
# 735      AirNaNWalker             15.0          50.0      85.0  100.0
# 614      Booster Gold             13.0          70.0      85.0   45.0
#
#      Durability  Power  Combat            FullName             AlterEgos  \
# 459       100.0  100.0    20.0                 NaN  No alter egos found.
# ...

# %%
HeroInfo.describe()
# Out:
#        Character Score  Intelligence    Strength       Speed  Durability  \
# count       748.000000    748.000000  748.000000  748.000000  748.000000
# mean          8.847594     50.868984   33.790107   32.660428   46.370321
# std          16.891520     32.792503   34.374893   27.566537   36.270596
# min           0.000000      0.000000    0.000000    0.000000    0.000000
# 25%           3.000000     25.000000   10.000000   10.000000   10.000000
# 50%           6.000000     60.000000   15.000000   30.000000   45.000000
# 75%           9.000000     75.000000   65.000000   50.000000   80.000000
# max         231.000000    100.000000  100.000000  100.000000  110.000000
#
#             Power      Combat
# count  748.000000  748.000000
# mean    50.942513   48.262032
# std     37.694796   33.144862
# min      0.000000    0.000000
# 25%     15.000000   15.000000
# 50%     50.000000   60.000000
# 75%     90.000000   75.000000
# max    100.000000  105.000000

# %%
import numpy as np

# %%
HeroInfo.describe(include=[np.number])
# Out:
#        Character Score  Intelligence    Strength       Speed  Durability  \
# count       748.000000    748.000000  748.000000  748.000000  748.000000
# mean          8.847594     50.868984   33.790107   32.660428   46.370321
# std          16.891520     32.792503   34.374893   27.566537   36.270596
# min           0.000000      0.000000    0.000000    0.000000    0.000000
# 25%           3.000000     25.000000   10.000000   10.000000   10.000000
# 50%           6.000000     60.000000   15.000000   30.000000   45.000000
# 75%           9.000000     75.000000   65.000000   50.000000   80.000000
# max         231.000000    100.000000  100.000000  100.000000  110.000000
#
#             Power      Combat
# count  748.000000  748.000000
# mean    50.942513   48.262032
# std     37.694796   33.144862
# min      0.000000    0.000000
# 25%     15.000000   15.000000
# 50%     50.000000   60.000000
# 75%     90.000000   75.000000
# max    100.000000  105.000000

# %%
np.object
# Out:
# object

# %%
HeroInfo.describe(include=[np.object]).T
# Out:
#                 count unique                   top freq
# Name              748    724         Green Lantern    7
# FullName          748    548                   NaN  168
# AlterEgos         748    136  No alter egos found.  608
# Aliases           748    488                   NaN  256
# PlaceOfBirth      748    243                   NaN  431
# FirstAppearance   748    562                   NaN  143
# Publisher         748     26         Marvel Comics  389
# Alignment         748      4                  good  502
# Gender            748      3                  Male  511
# Race              748     64                   NaN  307
# Height            748     71           NaN // 0 cm  221
# Weight            748    171        NaN lb // 0 kg  241
# EyeColor          748     25                  Blue  219
# HairColor         748     31                   NaN  184
# SkinColor         748     17                   NaN  675
# Occupation        748    384                   NaN  312
# ...

# %%
ch_sco = HeroInfo.groupby('Character Score').mean().round(3)

# %%
ch_sco.shape
# Out:
# (52, 6)

# %%
HeroInfo['Combat'].isnull().sum()
# Out:
# 0

# %%
HeroInfo.groupby('Name').std(ddof=0)['Combat'].head()
# Out:
# Name
# 3NaND Man      0.0
# ANaNBomb       0.0
# Abe Sapien     0.0
# Abin Sur       0.0
# Abomination    0.0
# Name: Combat, dtype: float64

# %%
import numpy as np

# %%
def std(x): return np.std(x)

# %%
HeroInfo.groupby(['Name','FirstAppearance']).agg(['size','sum','mean',std]).head()
# Out:
#                                                       Character Score        \
#                                                                  size   sum
# Name        FirstAppearance
# 3NaND Man   NaN                                                     1   4.0
# ANaNBomb    Hulk Vol 2 #2 (April, 2008) (as ANaNBomb)               1   9.0
# Abe Sapien  Hellboy: Seed of Destruction                            1  10.0
# Abin Sur    Showcase #22 (October, 1959)                            1   9.0
# Abomination Tales to Astonish #90                                   1   8.0
#
#                                                                  Intelligence  \
#                                                        mean  std         size
# Name        FirstAppearance
# 3NaND Man   NaN                                         4.0  0.0            1
# ANaNBomb    Hulk Vol 2 #2 (April, 2008) (as ANaNBomb)   9.0  0.0            1
# ...

# %%
def nanstd(x): return np.nanstd(x)

# %%
HeroInfo.Power.value_counts()
# Out:
# 0.0      171
# 100.0    165
# 30.0      37
# 55.0      37
# 60.0      30
# 50.0      29
# 25.0      27
# 70.0      26
# 75.0      25
# 40.0      25
# 45.0      24
# 35.0      23
# 90.0      19
# 65.0      19
# 85.0      18
# 80.0      18
# 20.0      17
# 95.0      15
# 15.0      12
# 10.0       8
# 5.0        3
# Name: Power, dtype: int64

# %%
HeroInfo.groupby(['Power']).agg(['size','sum','mean',nanstd]).head()
# Out:
#       Character Score                           Intelligence         \
#                  size   sum      mean    nanstd         size    sum
# Power
# 0.0               171   3.0  0.017544  0.228744          171   40.0
# 5.0                 3   6.0  2.000000  0.000000            3   30.0
# 10.0                8  42.0  5.250000  2.861381            8  490.0
# 15.0               12  70.0  5.833333  1.343710           12  795.0
# 20.0               17  84.0  4.941176  1.433654           17  935.0
#
#                             Strength           ...          Speed             \
#             mean     nanstd     size    sum    ...           mean     nanstd
# Power                                          ...
# 0.0     0.233918   3.049919      171   10.0    ...       0.029240   0.381240
# 5.0    10.000000   0.000000        3   30.0    ...      13.333333   2.357023
# 10.0   61.250000  34.072533        8   95.0    ...      26.875000  22.491318
# ...

# %%
HeroInfo.groupby(['Name','EyeColor','HairColor']).describe().round(3).head()
# Out:
#                                Character Score                              \
#                                          count  mean std   min   25%   50%
# Name        EyeColor HairColor
# 3NaND Man   Brown    Grey                  1.0   4.0 NaN   4.0   4.0   4.0
# ANaNBomb    Yellow   No Hair               1.0   9.0 NaN   9.0   9.0   9.0
# Abe Sapien  Blue     No Hair               1.0  10.0 NaN  10.0  10.0  10.0
# Abin Sur    Blue     No Hair               1.0   9.0 NaN   9.0   9.0   9.0
# Abomination Green    No Hair               1.0   8.0 NaN   8.0   8.0   8.0
#
#                                            Combat        ...   Speed        \
#                                  75%   max  count  mean  ...     75%   max
# Name        EyeColor HairColor                           ...
# 3NaND Man   Brown    Grey        4.0   4.0    1.0  55.0  ...    45.0  45.0
# ANaNBomb    Yellow   No Hair     9.0   9.0    1.0  65.0  ...    20.0  20.0
# ...

# %%
HeroInfo.groupby(['Name','FirstAppearance']).describe().round(3).fillna(0).head()
# Out:
#                                                       Character Score        \
#                                                                 count  mean
# Name        FirstAppearance
# 3NaND Man   NaN                                                   1.0   4.0
# ANaNBomb    Hulk Vol 2 #2 (April, 2008) (as ANaNBomb)             1.0   9.0
# Abe Sapien  Hellboy: Seed of Destruction                          1.0  10.0
# Abin Sur    Showcase #22 (October, 1959)                          1.0   9.0
# Abomination Tales to Astonish #90                                 1.0   8.0
#
#                                                                               \
#                                                        std   min   25%   50%
# Name        FirstAppearance
# 3NaND Man   NaN                                        0.0   4.0   4.0   4.0
# ANaNBomb    Hulk Vol 2 #2 (April, 2008) (as ANaNBomb)  0.0   9.0   9.0   9.0
# ...

# %%
HeroInfo.shape
# Out:
# (748, 24)

# %%
HeroInfo.pivot_table(index='Power',aggfunc=np.mean)
# Out:
#        Character Score     Combat  Durability  Intelligence      Speed  \
# Power
# 0.0           0.017544   0.058480    0.029240      0.233918   0.029240
# 5.0           2.000000  33.333333    8.333333     10.000000  13.333333
# 10.0          5.250000  24.375000   19.375000     61.250000  26.875000
# 15.0          5.833333  50.416667   39.583333     66.250000  21.250000
# 20.0          4.941176  59.411765   37.058824     55.000000  34.411765
# 25.0          5.000000  57.592593   37.962963     55.000000  28.148148
# 30.0          5.891892  66.486486   42.972973     62.432432  32.432432
# 35.0          6.130435  56.739130   48.695652     65.434783  35.000000
# 40.0          6.720000  65.200000   59.600000     65.200000  34.000000
# 45.0          6.166667  64.583333   53.750000     64.166667  30.000000
# 50.0          6.586207  70.517241   51.896552     66.206897  39.482759
# 55.0          6.081081  57.972973   55.000000     59.189189  32.837838
# ...

# %%
HeroInfo.pivot_table(index=['Power','EyeColor'],aggfunc=np.mean)
# Out:
#                     Character Score      Combat  Durability  Intelligence  \
# Power EyeColor
# 0.0   Black                0.000000    0.000000    0.000000      0.000000
#       Blue                 0.090909    0.303030    0.151515      1.212121
#       Brown                0.000000    0.000000    0.000000      0.000000
#       Green                0.000000    0.000000    0.000000      0.000000
#       Grey                 0.000000    0.000000    0.000000      0.000000
#       Hazel                0.000000    0.000000    0.000000      0.000000
#       NaN                  0.000000    0.000000    0.000000      0.000000
#       Red                  0.000000    0.000000    0.000000      0.000000
#       White                0.000000    0.000000    0.000000      0.000000
# 5.0   Brown                2.000000   40.000000    5.000000     10.000000
#       NaN                  2.000000   20.000000   15.000000     10.000000
# ...
