# %%
import pandas as pd

# %% [markdown]
# ## 예제 9-3  한글 처리하기

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.rcParams['font.size']
# Out:
# 10.0

# %%
plt.rcParams['font.family']
# Out:
# ['sans-serif']

# %%
rc_s = pd.Series(plt.rcParams)

# %%
rc_s.shape
# Out:
# (290,)

# %%
import sys

# %%
sys.platform
# Out:
# 'win32'

# %%
import matplotlib.font_manager as fm

# %%
if sys.platform == 'win32' :
    font_path = 'C:/Windows/Fonts/HANBatang.ttf'
    fontprop = fm.FontProperties(fname=font_path, size=18)
    
    path_pen = 'C:/Windows/Fonts/malgunbd.ttf'
    fontprop1 = fm.FontProperties(fname=path_pen, size=18)

# %%
if sys.platform == 'darwin'  :
    path = '/Users/plusjune/Library/Fonts/NanumMyeongjo.ttf'
    fontprop = fm.FontProperties(fname=path, size=18)
    path_pen = '/Users/plusjune/Library/Fonts/NanumPen.ttf'
    fontprop1 = fm.FontProperties(fname=path_pen, size=34)

# %%
plt.rcParams['font.family']
# Out:
# ['sans-serif']

# %%
if sys.platform == 'win32' :
    from matplotlib import font_manager, rc
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)

# %%
plt.rcParams['font.family']
# Out:
# ['Malgun Gothic']

# %%
import numpy as np

# %%
data = np.random.randint(1000, 6000, 50)

# %%
data
# Out:
# array([4728, 3193, 4437, 2113, 5690, 3932, 3685, 4313, 3345, 2694, 2007,
#        5619, 5864, 1458, 3735, 4669, 3189, 5100, 5168, 5537, 5757, 4965,
#        1477, 2332, 4089, 2410, 2567, 2988, 3262, 3978, 5905, 4053, 3924,
#        4805, 5037, 2115, 1952, 1174, 1234, 2013, 4543, 3442, 2903, 5736,
#        5729, 5976, 2275, 3612, 2600, 2539])

# %%
import matplotlib.pyplot as plt

# %%
plt.ylabel('가격', fontproperties=fontprop)
plt.title('시금치 가격변동 추이', fontproperties=fontprop)
plt.plot(range(50), data, 'r')
plt.show()

# %%
plt.plot(range(50), data, 'r')
plt.ylabel('가격', fontproperties=fontprop)
plt.title('시금치 가격변동 추이', fontproperties=fontprop1)
plt.show()

# %% [markdown]
# ## 예제 9-4  plot 그래프 그리기

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2016', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.head()
# Out:
# 2016-01-01   -1.325184
# 2016-01-02   -1.255338
# 2016-01-03   -1.435063
# 2016-01-04   -1.198977
# 2016-01-05   -2.079678
# Freq: D, dtype: float64

# %%
ts.plot()
plt.show()

# %%
ts.plot

# %%
for i in dir(ts.plot) :
    if not i.startswith("_") :
        print(i, end=",  ")
# Out:
# area,  bar,  barh,  box,  density,  hist,  kde,  line,  pie,

# %%
ts.plot.line
# Out:
# <bound method SeriesPlotMethods.line of <pandas.plotting._core.SeriesPlotMethods object at 0x0000000007BA0B70>>

# %%
ts.plot.line.__func__
# Out:
# <function pandas.plotting._core.SeriesPlotMethods.line>

# %%
ts.plot.line()

# %%
ts.plot(kind='line')

# %%
ts.index[:10]
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(1000, 4), 
                  index=ts.index, 
                  columns=list('가나다라'))

# %%
df = df.cumsum()

# %%
df.head()
# Out:
#                    가         나         다         라
# 2016-01-01 -0.020549 -0.529883  0.840249 -0.122905
# 2016-01-02  2.483140  1.262024  0.785421  1.086601
# 2016-01-03  2.532777  0.905410  1.094334 -0.846025
# 2016-01-04  3.101976 -0.032999  1.391356 -2.072524
# 2016-01-05  2.423123  0.989175  0.817417 -2.808705

# %%
df.plot(title="한글")
plt.show()

# %%
df.plot.line().legend(['A_가','B_나','C_다','D_라'])

# %%
df.plot(x=df.index, y='나')

# %%
df.plot.line(x=df.index, y='나')

# %% [markdown]
# ## 예제 9-5  복잡한 plot 그래프 그리기

# %%
import numpy as np

# %%
ser = pd.Series(np.random.randn(10000))

# %%
ser.plot.kde()

# %%
ser1 = pd.Series(np.random.rand(10000))

# %%
ser1.plot.kde()

# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.plot()

# %%
df.species.value_counts()
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'species')

# %%
from pandas.plotting import parallel_coordinates

# %%
parallel_coordinates(df, 'species')

# %%
from pandas.plotting import autocorrelation_plot

# %%
import numpy as np

# %%
dr = pd.date_range(start='2017-01-01', end='2017-12-31')

df = pd.DataFrame(np.arange(len(dr)), index=dr, columns=["Values"])

# %%
df.head()
# Out:
#             Values
# 2017-01-01       0
# 2017-01-02       1
# 2017-01-03       2
# 2017-01-04       3
# 2017-01-05       4

# %%
autocorrelation_plot(df)
plt.show()

# %%
import numpy as np

# %%
data = pd.Series(np.random.rand(1000))

# %%
data.plot()

# %%
data.plot.hist(bins=50,rwidth=0.9, color='grey')

# %%
from pandas.plotting import bootstrap_plot

# %%
bootstrap_plot(data, size=50, samples=500, color='grey')

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)
